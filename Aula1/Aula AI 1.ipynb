# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheuspz/DISCIPLINA-FUNDAMENTOS-DE-IA/blob/main/Aula%20AI%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AULA IA

# %%
print("Hello World")
# Out:
# Hello World
